# %%
import os, sys
import pandas as pd
from IPython.display import clear_output

import numpy as np

import warnings

from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", message="numpy.dtype size changed")
warnings.filterwarnings("ignore", message="numpy.ufunc size changed")
pd.options.mode.chained_assignment = None
from sklearn.manifold import TSNE
from transformers import AutoModel, AutoProcessor
from PIL import Image
from torchvision import transforms
import torch
import scripts.utils as utils

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# directory & file hierarchy
proj_dir = os.path.abspath('../..')
stimuli_dir = os.path.join(proj_dir,'stimuli')
results_dir = os.path.join(proj_dir,'results')
plot_dir = os.path.join(results_dir,'plots')
ms_plot_dir = os.path.join(plot_dir,'ms')
analysis_dir = os.path.join(proj_dir,'analysis')
data_dir = os.path.join(proj_dir,'data')
# plot_dir = os.path.join(results_dir,'plots')
# csv_dir = os.path.join(results_dir,'csv')
exp_dir = os.path.abspath(os.path.join(proj_dir,'experiments'))

## add helpers to python path
if os.path.join(proj_dir,'utils') not in sys.path:
    sys.path.append(os.path.join(proj_dir,'utils'))

def make_dir_if_not_exists(dir_name):   
    if not os.path.exists(dir_name):
        os.makedirs(dir_name)
    return dir_name

# %%
things_main_df = pd.read_csv(os.path.join(data_dir, 'things_concepts.tsv'), sep='\t') ### things concepts metadata
things_plus_df= pd.read_csv(os.path.join(data_dir,'THINGSplus_categories.tsv'),sep='\t')
things_plus_dict = dict(zip(things_plus_df.uniqueID, things_plus_df.category))

# %%
things_plus_dict
# Out:
# {'aardvark': 'mammal',
#  'alligator': 'animal',
#  'alpaca': 'mammal',
#  'ant': 'insect',
#  'anteater': 'mammal',
#  'antelope': 'mammal',
#  'badger': 'mammal',
#  'barnacle': 'sea animal',
#  'bat1': 'mammal',
#  'bear': 'mammal',
#  'beaver': 'mammal',
#  'bee': 'insect',
#  'beetle': 'insect',
#  'bird': 'bird',
#  'bison': 'mammal',
#  'blowfish': 'seafood',
#  'boar': 'mammal',
#  'bug': 'insect',
#  'bull': 'mammal',
#  'butterfly': 'insect',
#  'calf1': 'mammal',
#  'camel': 'mammal',
#  'cardinal': 'bird',
#  'cat': 'mammal',
#  'caterpillar': 'insect',
#  'catfish': 'seafood',
#  'cheetah': 'mammal',
#  'chick': 'bird',
#  'chicken2': 'farm animal',
#  'chihuahua': 'mammal',
#  'chinchilla': 'mammal',
#  'chipmunk': 'mammal',
#  'clam': 'seafood',
#  'cobra': 'animal',
#  'cockatoo': 'bird',
#  'cockroach': 'insect',
#  'coral': 'sea animal',
#  'cougar': 'mammal',
#  'cow': 'mammal',
#  'coyote': 'mammal',
#  'crab': 'seafood',
#  'crayfish': 'seafood',
#  'crow': 'bird',
#  'dalmatian': 'mammal',
#  'deer': 'mammal',
#  'dog': 'mammal',
#  'dolphin': 'sea animal',
#  'donkey': 'mammal',
#  'dragonfly': 'insect',
#  'duck': 'farm animal',
#  'duckling': 'bird',
#  'eagle': 'bird',
#  'earwig': 'insect',
#  'eel': 'seafood',
#  'elephant': 'mammal',
#  'ferret': 'mammal',
#  'fish': 'seafood',
#  'flamingo': 'bird',
#  'fly': 'insect',
#  'fox': 'mammal',
#  'frog': 'animal',
#  'gazelle': 'mammal',
#  'giraffe': 'mammal',
#  'goat': 'mammal',
#  'goldfish': 'animal',
#  'goose': 'food',
#  'gopher': 'mammal',
#  'gorilla': 'mammal',
#  'grasshopper': 'insect',
#  'groundhog': 'mammal',
#  'guinea_pig': 'mammal',
#  'hamster': 'mammal',
#  'hawk': 'bird',
#  'hedgehog': 'mammal',
#  'hippopotamus': 'mammal',
#  'horse': 'mammal',
#  'hummingbird': 'bird',
#  'hyena': 'mammal',
#  'iguana': 'animal',
#  'jellyfish': 'seafood',
#  'kangaroo': 'mammal',
#  'kitten': 'mammal',
#  'koala': 'mammal',
#  'ladybug': 'insect',
#  'lamb': 'mammal',
#  'leech': 'animal',
#  'leopard': 'mammal',
#  'lightning_bug': 'insect',
#  'lion': 'mammal',
#  'lizard': 'animal',
#  'llama': 'mammal',
#  'lobster': 'seafood',
#  'maggot': 'animal',
#  'manatee': 'sea animal',
#  'meerkat': 'mammal',
#  'mole': 'mammal',
#  'mongoose': 'mammal',
#  'monkey': 'mammal',
#  'moose': 'mammal',
#  'mosquito': 'insect',
#  'moth': 'insect',
#  'mouse1': 'mammal',
#  'mussel': 'seafood',
#  'octopus': 'seafood',
#  'orangutan': 'mammal',
#  'ostrich': 'bird',
#  'otter': 'mammal',
#  'owl': 'bird',
#  'oyster': 'seafood',
#  'panda': 'mammal',
#  'panther': 'mammal',
#  'parrot': 'bird',
#  'peacock': 'bird',
#  'pelican': 'bird',
#  'penguin': 'bird',
#  'pheasant': 'bird',
#  'pig': 'mammal',
#  'pigeon': 'bird',
#  'piglet': 'mammal',
#  'platypus': 'mammal',
#  'polar_bear': 'mammal',
#  'pony': 'mammal',
#  'poodle': 'mammal',
#  'porcupine': 'mammal',
#  'possum': 'mammal',
#  'praying_mantis': 'insect',
#  'puffin': 'bird',
#  'pug': 'mammal',
#  'puppy': 'mammal',
#  'rabbit': 'mammal',
#  'raccoon': 'mammal',
#  'ram': 'mammal',
#  'rat': 'mammal',
#  'rattlesnake': 'animal',
#  'reindeer': 'mammal',
#  'rhinoceros': 'mammal',
#  'rooster': 'farm animal',
#  'sardine': 'seafood',
#  'scallop': 'seafood',
#  'scorpion': 'animal',
#  'sea_urchin': 'seafood',
#  'seagull': 'bird',
#  'seahorse': 'sea animal',
#  'seal': 'sea animal',
#  'shark': 'seafood',
#  'sheep': 'mammal',
#  'shrimp': 'seafood',
#  'skunk': 'mammal',
#  'sloth': 'mammal',
#  'slug': 'animal',
#  'snail': 'seafood',
#  'snake': 'animal',
#  'spider': 'animal',
#  'squid': 'seafood',
#  'squirrel': 'mammal',
#  'starfish': 'sea animal',
#  'stingray': 'sea animal',
#  'swan': 'bird',
#  'swordfish': 'seafood',
#  'tadpole': 'animal',
#  'tarantula': 'animal',
#  'tick': 'animal',
#  'tiger': 'mammal',
#  'toad': 'animal',
#  'toucan': 'bird',
#  'turkey': 'food',
#  'turtle': 'sea animal',
#  'vulture': 'bird',
#  'walrus': 'sea animal',
#  'warthog': 'mammal',
#  'wasp': 'insect',
#  'weasel': 'mammal',
#  'whale': 'sea animal',
#  'wolf': 'mammal',
#  'worm': 'animal',
#  'yak': 'mammal',
#  'zebra': 'mammal',
#  'bead': 'arts and crafts supply',
#  'button1': 'fastener',
#  'canvas': 'arts and crafts supply',
#  'cardboard': 'arts and crafts supply',
#  'chalk': 'school supply',
#  'charcoal': 'arts and crafts supply',
#  'chisel': 'tool',
#  'clay': 'arts and crafts supply',
#  'crayon': 'toy',
#  'easel': 'arts and crafts supply',
#  'eraser': 'school supply',
#  'fountain_pen': 'tool',
#  'glue': 'school supply',
#  'ink': 'school supply',
#  'knitting_needle': 'arts and crafts supply',
#  'loom': 'arts and crafts supply',
#  'marble': 'toy',
#  'marker': 'tool',
#  'mold1': 'container',
#  'needle': 'tool',
#  'paint': 'arts and crafts supply',
#  'paintbrush': 'tool',
#  'palette': 'arts and crafts supply',
#  'paper': 'school supply',
#  'patch': 'clothing accessory',
#  'pen': 'tool',
#  'pencil': 'tool',
#  'pencil_sharpener': 'tool',
#  'pin': 'tool',
#  'pincushion': 'arts and crafts supply',
#  'pom-pom': 'arts and crafts supply',
#  'ribbon': 'arts and crafts supply',
#  'scissors': 'weapon',
#  'sequin': 'arts and crafts supply',
#  'sewing_kit': 'arts and crafts supply',
#  'sewing_machine': 'home appliance',
#  'stamp2': 'tool',
#  'tape': 'office supply',
#  'thimble': 'arts and crafts supply',
#  'thread': 'arts and crafts supply',
#  'wire': 'hardware',
#  'wire_cutters': 'tool',
#  'wrapping_paper': 'arts and crafts supply',
#  'yarn': 'arts and crafts supply',
#  'ankle': 'body part',
#  'arm': 'body part',
#  'beard': 'body part',
#  'bone': 'body part',
#  'calf2': 'body part',
#  'chest1': 'body part',
#  'chin': 'body part',
#  'ear': 'body part',
#  'elbow': 'body part',
#  'eye': 'body part',
#  'face': 'body part',
#  'finger': 'body part',
#  'foot': 'body part',
#  'hair': 'body part',
#  'hand': 'body part',
#  'hip': 'body part',
#  'knee': 'body part',
#  'leg': 'body part',
#  'mouth': 'body part',
#  'mustache': 'body part',
#  'navel': 'body part',
#  'neck': 'body part',
#  'nose': 'body part',
#  'shoulder': 'body part',
#  'skeleton': 'body part',
#  'skin': 'body part',
#  'skull': 'body part',
#  'stomach': 'body part',
#  'thumb': 'body part',
#  'toe': 'body part',
#  'tongue': 'body part',
#  'tooth': 'body part',
#  'torso': 'body part',
#  'wrist': 'body part',
#  'bacon': 'food',
#  'bagel': 'food',
#  'bread': 'food',
#  'breakfast': 'food',
#  'cereal': 'food',
#  'cream_cheese': 'food',
#  'crepe': 'food',
#  'croissant': 'food',
#  'donut': 'food',
#  'egg': 'food',
#  'french_fries': 'food',
#  'granola': 'food',
#  'grits': 'food',
#  'ham': 'food',
#  'hamburger': 'food',
#  'hash': 'food',
#  'honey': 'food',
#  'jam': 'food',
#  'maple_syrup': 'food',
#  'marmalade': 'food',
#  'muffin': 'food',
#  'oatmeal': 'food',
#  'omelet': 'food',
#  'pancake': 'food',
#  'pastry': 'food',
#  'peanut_butter': 'food',
#  'roll': 'food',
#  'sandwich': 'food',
#  'sausage': 'food',
#  'scone': 'food',
#  'scrambled_egg': 'food',
#  'syrup': 'food',
#  'toast': 'food',
#  'waffle': 'food',
#  'yogurt': 'food',
#  'candy': 'food',
#  'candy_bar': 'food',
#  'candy_cane': 'food',
#  'caramel': 'food',
#  'chocolate': 'food',
#  'cotton_candy': 'food',
#  'fudge': 'food',
#  'gum': 'food',
#  'gumball': 'food',
#  'gumdrop': 'food',
#  'jelly_bean': 'food',
#  'licorice': 'food',
#  'lollipop': 'food',
#  'marshmallow': 'food',
#  'peppermint': 'food',
#  'taffy': 'food',
#  'apron': 'protective clothing',
#  'armor': 'safety equipment',
#  'bandanna': 'headwear',
#  'bathrobe': 'clothing',
#  'beanie': 'headwear',
#  'belt': 'clothing accessory',
#  'bikini': "women's clothing",
#  'blazer': 'outerwear',
#  'blouse': "women's clothing",
#  'boa': "women's clothing",
#  'bolo_tie': 'clothing accessory',
#  'bonnet': 'headwear',
#  'boot': 'footwear',
#  'bow1': 'fastener',
#  'bowler_hat': 'headwear',
#  'bowtie': 'clothing accessory',
#  'boxer_shorts': 'clothing',
#  'bra': "women's clothing",
#  'bracelet1': 'clothing accessory',
#  'bulletproof_vest': 'safety equipment',
#  'cape': 'outerwear',
#  'cardigan': 'clothing',
#  'chaps': 'clothing',
#  'cloak': 'outerwear',
#  'clothes': 'clothing',
#  'coat': 'outerwear',
#  'corset': "women's clothing",
#  'costume': 'clothing',
#  'coverall': 'safety equipment',
#  'crown': 'jewelry',
#  'cummerbund': 'clothing accessory',
#  'diaper': 'personal hygiene item',
#  'dress': "women's clothing",
#  'eye_patch': 'medical equipment',
#  'fishnet_stockings': "women's clothing",
#  'flip_flop': 'footwear',
#  'fur_coat': 'outerwear',
#  'garter': "women's clothing",
#  'glove': 'protective clothing',
#  'hat': 'headwear',
#  'headband': 'headwear',
#  'headdress': 'headwear',
#  'headscarf': "women's clothing",
#  'hoodie': 'clothing',
#  'jacket': 'outerwear',
#  'jeans': 'clothing',
#  'jersey': 'clothing',
#  'jumpsuit': 'outerwear',
#  'kilt': 'clothing',
#  'kimono': "women's clothing",
#  'lab_coat': 'scientific equipment',
#  'leggings': "women's clothing",
#  'leotard': 'clothing',
#  'life_jacket': 'safety equipment',
#  'lingerie': "women's clothing",
#  'loincloth': 'clothing',
#  'mitten': 'clothing accessory',
#  'moccasin': 'footwear',
#  'muff': 'clothing accessory',
#  'nightshirt': 'clothing',
#  'outfit': 'clothing',
#  'overalls': 'protective clothing',
#  'pajamas': 'clothing',
#  'panties': 'clothing',
#  'pants': 'clothing',
#  'pantsuit': "women's clothing",
#  'pantyhose': "women's clothing",
#  'polo_shirt': 'clothing',
#  'raincoat': 'protective clothing',
#  'robe': 'clothing',
#  'sandal': 'footwear',
#  'scarf': 'outerwear',
#  'shawl': 'outerwear',
#  'shirt': 'clothing',
#  'shoe': 'footwear',
#  'shorts': 'clothing',
#  'ski_boots': 'sports equipment',
#  'skirt': "women's clothing",
#  'slipper': 'footwear',
#  'snowshoe': 'sports equipment',
#  'snowsuit': 'outerwear',
#  'sock': 'footwear',
#  'sombrero': 'headwear',
#  'spacesuit': 'safety equipment',
#  'stiletto': "women's clothing",
#  'stockings': "women's clothing",
#  'straightjacket': 'clothing',
#  'suit': 'clothing',
#  'suspenders': 'clothing accessory',
#  'sweater': 'clothing',
#  'sweatsuit': 'clothing',
#  'swimsuit': 'clothing',
#  't-shirt': 'clothing',
#  'tiara': "women's clothing",
#  'tie': 'clothing accessory',
#  'toga': 'clothing',
#  'top_hat': 'headwear',
#  'tube_top': "women's clothing",
#  'turban': 'headwear',
#  'turtleneck': 'clothing',
#  'tuxedo': 'clothing',
#  'undershirt': 'clothing',
#  'underwear': 'clothing',
#  'uniform': 'clothing',
#  'veil': "women's clothing",
#  'vest': 'clothing',
#  'visor': 'protective clothing',
#  'wetsuit': 'sports equipment',
#  'belt_buckle': 'fastener',
#  'bracelet2': 'jewelry',
#  'brooch': 'jewelry',
#  'buckle': 'fastener',
#  'corsage': 'clothing accessory',
#  'cufflink': 'jewelry',
#  'earring': 'jewelry',
#  'glasses': 'clothing accessory',
#  'handkerchief': 'clothing accessory',
#  'insole': 'clothing accessory',
#  'lanyard': 'clothing accessory',
#  'purse': 'container',
#  'watch': 'jewelry',
#  'applesauce': 'food',
#  'butter': 'food',
#  'ginger': 'food',
#  'gravy': 'food',
#  'ketchup': 'food',
#  'mustard': 'food',
#  'pesto': 'food',
#  'sauce': 'food',
#  'soy_sauce': 'food',
#  'blowtorch': 'weapon',
#  'bulldozer': 'vehicle',
#  'cement_mixer': 'construction equipment',
#  'chain': 'tool',
#  'chainsaw': 'weapon',
#  'crane': 'construction equipment',
#  'drill': 'tool',
#  'hammer': 'weapon',
#  'helmet': 'sports equipment',
#  'jackhammer': 'tool',
#  'pliers': 'tool',
#  'pulley': 'construction equipment',
#  'pump': 'construction equipment',
#  'rope': 'tool',
#  'saw': 'tool',
#  'sawhorse': 'tool',
#  'scaffold': 'construction equipment',
#  'scaffolding': 'construction equipment',
#  'screwdriver': 'tool',
#  'shovel': 'tool',
#  'sledgehammer': 'tool',
#  'staple_gun': 'tool',
#  'steamroller': 'vehicle',
#  'tarp': 'construction equipment',
#  'trowel': 'tool',
#  'wheelbarrow': 'container',
#  'wrench': 'tool',
#  'aquarium': 'home decor',
#  'ashtray': 'container',
#  'backpack': 'school supply',
#  'bag': 'container',
#  'ballot_box': 'container',
#  'bank': 'container',
#  'barrel': 'container',
#  'basket': 'container',
#  'bathtub': 'container',
#  'beaker': 'scientific equipment',
#  'bedpan': 'medical equipment',
#  'bin': 'container',
#  'birdbath': 'home decor',
#  'birdcage': 'home decor',
#  'bottle': 'container',
#  'bowl': 'container',
#  'box': 'container',
#  'breadbox': 'container',
#  'briefcase': 'container',
#  'bucket': 'container',
#  'cabinet': 'furniture',
#  'cage': 'container',
#  'can': 'container',
#  'canister': 'container',
#  'chest2': 'furniture',
#  'closet': 'furniture',
#  'coffee_pot': 'container',
#  'coffin': 'container',
#  'container': 'container',
#  'cooker': 'kitchen appliance',
#  'coop': 'container',
#  'crate': 'container',
#  'cup': 'container',
#  'doghouse': 'container',
#  'drawer': 'container',
#  'dresser': 'furniture',
#  'duffel_bag': 'container',
#  'dumpster': 'container',
#  'dustpan': 'tool',
#  'filing_cabinet': 'furniture',
#  'fishbowl': 'container',
#  'flask': 'container',
#  'footbath': 'container',
#  'glass': 'container',
#  'goblet': 'container',
#  'hatbox': 'container',
#  'honeypot': 'container',
#  'hot-water_bottle': 'container',
#  'hot_tub': 'container',
#  'inkwell': 'school supply',
#  'jar': 'container',
#  'jug': 'container',
#  'keg': 'container',
#  'kettle': 'kitchen tool',
#  'locker': 'container',
#  'luggage': 'container',
#  'lunchbox': 'school supply',
#  'mailbox': 'container',
#  'matchbox': 'container',
#  'measuring_cup': 'scientific equipment',
#  'mug': 'container',
#  'nightstand': 'furniture',
#  'oilcan': 'container',
#  'pan': 'container',
#  'paper_bag': 'container',
#  'petri_dish': 'scientific equipment',
#  'piggy_bank': 'container',
#  'pillbox': 'medical equipment',
#  'pitcher': 'container',
#  'pocket': 'container',
#  'pot': 'container',
#  'saltshaker': 'container',
#  'sandbag': 'container',
#  'sarcophagus': 'container',
#  'shaker': 'container',
#  'shopping_basket': 'container',
#  'shopping_cart': 'container',
#  'suitcase': 'container',
#  'swimming_pool': 'container',
#  'syringe': 'scientific equipment',
#  'tank2': 'scientific equipment',
#  'teacup': 'container',
#  'teapot': 'container',
#  'tent': 'container',
#  'terrarium': 'home decor',
#  'test_tube': 'scientific equipment',
#  'thermos': 'container',
#  'toolbox': 'container',
#  'trashcan': 'container',
#  'trunk': 'container',
#  'tupperware': 'container',
#  'urn': 'container',
#  'vase': 'home decor',
#  'vial': 'medical equipment',
#  'wallet': 'container',
#  'water_bottle': 'container',
#  'water_heater': 'home appliance',
#  'watering_can': 'tool',
#  'wine_bottle': 'container',
#  'wine_cooler': 'home appliance',
#  'wineglass': 'container',
#  'wok': 'container',
#  'baklava': 'food',
#  'banana_split': 'food',
#  'birthday_cake': 'food',
#  'brownie': 'food',
#  'cake': 'food',
#  'cake_mix': 'food',
#  'cheese': 'food',
#  'cheesecake': 'food',
#  'cookie': 'food',
#  'creme_brulee': 'food',
#  'cupcake': 'food',
#  'dessert': 'food',
#  'eclair': 'food',
#  'flan': 'food',
#  'fruitcake': 'food',
#  'ice-cream_cone': 'food',
#  'ice_cream': 'food',
#  'milkshake': 'drink',
#  'mousse': 'food',
#  'parfait': 'food',
#  'pie': 'food',
#  'popsicle': 'food',
#  'pudding': 'food',
#  'shortbread': 'food',
#  'sorbet': 'food',
#  'souffle': 'food',
#  'sundae': 'food',
#  'tiramisu': 'food',
#  'wedding_cake': 'food',
#  'whipped_cream': 'food',
#  'beer': 'drink',
#  'champagne': 'drink',
#  'cocktail': 'drink',
#  'coffee': 'drink',
#  'drink': 'drink',
#  'eggnog': 'drink',
#  'espresso': 'drink',
#  'hot_chocolate': 'drink',
#  'juice': 'drink',
#  'latte': 'drink',
#  'lemonade': 'drink',
#  'margarita': 'drink',
#  'milk': 'drink',
#  'punch1': 'drink',
#  'smoothie': 'drink',
#  'soda': 'drink',
#  'tea': 'drink',
#  'wine': 'drink',
#  'air_conditioner': 'home appliance',
#  'amplifier': 'electronic device',
#  'blender': 'kitchen appliance',
#  'blower': 'tool',
#  'camcorder': 'electronic device',
#  'camera2': 'electronic device',
#  'cash_machine': 'electronic device',
#  'cd_player': 'electronic device',
#  'cellphone': 'electronic device',
#  'centrifuge': 'scientific equipment',
#  'coffeemaker': 'kitchen appliance',
#  'computer': 'game',
#  'computer_screen': 'electronic device',
#  'copier': 'electronic device',
#  'curling_iron': 'tool',
#  'defibrillator': 'medical equipment',
#  'dishwasher': 'kitchen appliance',
#  'dryer': 'home appliance',
#  'electric_chair': 'electronic device',
#  'fan': 'home appliance',
#  'food_processor': 'kitchen appliance',
#  'freezer': 'kitchen appliance',
#  'generator': 'electronic device',
#  'hairdryer': 'personal hygiene item',
#  'hotplate': 'kitchen appliance',
#  'icemaker': 'kitchen appliance',
#  'incubator': 'scientific equipment',
#  'iron': 'home appliance',
#  'joystick': 'electronic device',
#  'juicer2': 'kitchen appliance',
#  'jukebox': 'electronic device',
#  'lamp': 'lighting',
#  'laptop': 'electronic device',
#  'metal_detector': 'tool',
#  'microphone': 'electronic device',
#  'microwave': 'kitchen appliance',
#  'mixer': 'kitchen appliance',
#  'modem': 'electronic device',
#  'mouse2': 'electronic device',
#  'music_box': 'toy',
#  'pinball': 'game',
#  'polygraph': 'scientific equipment',
#  'printer': 'electronic device',
#  'projector': 'electronic device',
#  'radio': 'electronic device',
#  'record_player': 'electronic device',
#  'refrigerator': 'kitchen appliance',
#  'remote_control': 'electronic device',
#  'router': 'electronic device',
#  'scanner': 'electronic device',
#  'screen1': 'electronic device',
#  'shredder': 'electronic device',
#  'slicer': 'kitchen appliance',
#  'slot_machine': 'game',
#  'smoke_alarm': 'safety equipment',
#  'stereo': 'electronic device',
#  'tablet': 'electronic device',
#  'tape_recorder': 'electronic device',
#  'television': 'home appliance',
#  'toaster': 'kitchen appliance',
#  'toaster_oven': 'kitchen appliance',
#  'treadmill': 'sports equipment',
#  'turntable': 'electronic device',
#  'vacuum': 'tool',
#  'vending_machine': 'electronic device',
#  'waffle_iron': 'kitchen appliance',
#  'washing_machine': 'home appliance',
#  'webcam': 'electronic device',
#  'barrette': 'jewelry',
#  'bolt': 'hardware',
#  'clasp': 'hardware',
#  'clothespin': 'fastener',
#  'combination_lock': 'hardware',
#  'gasket': 'part of car',
#  'hairpin': 'jewelry',
#  'hook1': 'hardware',
#  'knot': 'fastener',
#  'latch': 'hardware',
#  'lock': 'hardware',
#  'nail': 'hardware',
#  'padlock': 'hardware',
#  'paperclip': 'school supply',
#  'peg': 'hardware',
#  'rubber_band': 'office supply',
#  'safety_pin': 'fastener',
#  'screw': 'hardware',
#  'staple': 'office supply',
#  'strap': 'fastener',
#  'tack': 'office supply',
#  'thumbtack': 'office supply',
#  'velcro': 'fastener',
#  'zipper': 'fastener',
#  'almond': 'food',
#  'appetizer': 'food',
#  'apple': 'fruit',
#  'artichoke': 'vegetable',
#  'arugula': 'vegetable',
#  'asparagus': 'vegetable',
#  'avocado': 'fruit',
#  'banana': 'fruit',
#  'basil': 'plant',
#  'batter': 'food',
#  'bean': 'food',
#  'beet': 'vegetable',
#  'bell_pepper': 'vegetable',
#  'berry': 'fruit',
#  'biscuit': 'food',
#  'blackberry': 'fruit',
#  'blueberry': 'fruit',
#  'bok_choy': 'vegetable',
#  'bologna': 'food',
#  'breadstick': 'food',
#  'broccoli': 'vegetable',
#  'brussels_sprouts': 'vegetable',
#  'buffet': 'food',
#  'bun': 'food',
#  'burrito': 'food',
#  'cabbage': 'vegetable',
#  'calamari': 'seafood',
#  'calzone': 'food',
#  'cantaloupe': 'fruit',
#  'carrot': 'vegetable',
#  'cashew': 'food',
#  'casserole': 'food',
#  'cauliflower': 'vegetable',
#  'caviar': 'seafood',
#  'celery': 'vegetable',
#  'cheeseburger': 'food',
#  'cherry': 'fruit',
#  'chicken1': 'food',
#  'chickpea': 'vegetable',
#  'chili': 'food',
#  'chips': 'food',
#  'chive': 'vegetable',
#  'cilantro': 'vegetable',
#  'cinnamon': 'food',
#  'clove': 'food',
#  'coconut': 'fruit',
#  'coffee_bean': 'food',
#  'coleslaw': 'food',
#  'cordon_bleu': 'food',
#  'corn': 'vegetable',
#  'cornbread': 'food',
#  'cornmeal': 'food',
#  'cracker': 'food',
#  'cranberry': 'fruit',
#  'crouton': 'food',
#  'crumb': 'food',
#  'cucumber': 'vegetable',
#  'curry': 'food',
#  'dip': 'food',
#  'dough': 'food',
#  'dumpling': 'food',
#  'easter_egg': 'food',
#  'egg_roll': 'food',
#  'eggplant': 'vegetable',
#  'enchilada': 'food',
#  'fast_food': 'food',
#  'fig': 'fruit',
#  'flour': 'food',
#  'fondue': 'food',
#  'fruit': 'fruit',
#  'garlic': 'vegetable',
#  'gingerbread_man': 'food',
#  'grain': 'food',
#  'grape': 'fruit',
#  'grapefruit': 'fruit',
#  'green_beans': 'vegetable',
#  'guacamole': 'food',
#  'gyro': 'food',
#  'hotdog': 'food',
#  'hummus': 'food',
#  'jalapeno': 'vegetable',
#  'kale': 'vegetable',
#  'kebab': 'food',
#  'kiwi': 'fruit',
#  'lamb_chop': 'food',
#  'lasagna': 'food',
#  'leek': 'vegetable',
#  'lemon': 'fruit',
#  'lettuce': 'vegetable',
#  'lime': 'fruit',
#  'macadamia': 'food',
#  'macaroni': 'food',
#  'mango': 'fruit',
#  'mashed_potato': 'food',
#  'meat': 'food',
#  'meatball': 'food',
#  'meatloaf': 'food',
#  'melon': 'fruit',
#  'mint': 'plant',
#  'mulberry': 'fruit',
#  'mushroom': 'food',
#  'nacho': 'food',
#  'noodle': 'food',
#  'nut': 'food',
#  'okra': 'vegetable',
#  'olive': 'food',
#  'onion': 'vegetable',
#  'orange': 'fruit',
#  'papaya': 'fruit',
#  'parsley': 'vegetable',
#  'pasta': 'food',
#  'patty': 'food',
#  'pea': 'vegetable',
#  'peach': 'fruit',
#  'peanut': 'food',
#  'pear': 'fruit',
#  'pecan': 'food',
#  'pepper1': 'food',
#  'pepper2': 'vegetable',
#  'pepperoni': 'food',
#  'pickle': 'food',
#  'piecrust': 'food',
#  'pineapple': 'fruit',
#  'pistachio': 'food',
#  'pita': 'food',
#  'pizza': 'food',
#  'plum': 'fruit',
#  'pomegranate': 'fruit',
#  'popcorn': 'food',
#  'poppy': 'plant',
#  'potato': 'vegetable',
#  'potpie': 'food',
#  'pretzel': 'food',
#  'prune': 'fruit',
#  'pumpkin': 'vegetable',
#  'quesadilla': 'food',
#  'quiche': 'food',
#  'radish': 'vegetable',
#  'raisin': 'fruit',
#  'raspberry': 'fruit',
#  'ravioli': 'food',
#  'ready_meal': 'food',
#  'rhubarb': 'vegetable',
#  'rice': 'food',
#  'saffron': 'food',
#  'salad': 'food',
#  'salami': 'food',
#  'sauerkraut': 'food',
#  'scallion': 'vegetable',
#  'seafood': 'seafood',
#  'seaweed': 'seafood',
#  'snack': 'food',
#  'soup': 'food',
#  'spaghetti': 'food',
#  'spam': 'food',
#  'spareribs': 'food',
#  'spinach': 'vegetable',
#  'spring_roll': 'food',
#  'sprouts': 'vegetable',
#  'squash': 'vegetable',
#  'star_fruit': 'fruit',
#  'steak': 'food',
#  'stew': 'food',
#  'stir_fry': 'food',
#  'strawberry': 'fruit',
#  'string_cheese': 'food',
#  'stuffing': 'food',
#  'sugar_cube': 'food',
#  'sushi': 'food',
#  'sweet_potato': 'vegetable',
#  'taco': 'food',
#  'tamale': 'food',
#  'tomato': 'vegetable',
#  'tomato_sauce': 'food',
#  'tortellini': 'food',
#  'tortilla': 'food',
#  'tostada': 'food',
#  'vegetable': 'vegetable',
#  'wafer': 'food',
#  'walnut': 'food',
#  'watermelon': 'fruit',
#  'wheat': 'food',
#  'wrap': 'food',
#  'yolk': 'food',
#  'zucchini': 'vegetable',
#  'flipper': 'sports equipment',
#  'iceskate': 'sports equipment',
#  'rollerblade': 'sports equipment',
#  'rollerskate': 'sports equipment',
#  'air_mattress': 'furniture',
#  'bassinet': 'furniture',
#  'beanbag': 'furniture',
#  'bed': 'furniture',
#  'bench': 'furniture',
#  'bookshelf': 'furniture',
#  'bunkbed': 'furniture',
#  'chair': 'furniture',
#  'coat_rack': 'furniture',
#  'coffee_table': 'furniture',
#  'cot': 'furniture',
#  'couch': 'furniture',
#  'counter': 'furniture',
#  'crib': 'furniture',
#  'desk': 'furniture',
#  'footrest': 'furniture',
#  'hammock': 'furniture',
#  'highchair': 'furniture',
#  'lectern': 'furniture',
#  'loveseat': 'furniture',
#  'mattress': 'furniture',
#  'ottoman': 'furniture',
#  'rack1': 'furniture',
#  'rack2': 'furniture',
#  'recliner': 'furniture',
#  'rocking_chair': 'furniture',
#  'shelf': 'furniture',
#  'sofa_bed': 'furniture',
#  'step_stool': 'furniture',
#  'stool': 'furniture',
#  'table': 'furniture',
#  'throne': 'furniture',
#  'workbench': 'furniture',
#  'backgammon': 'game',
#  'board_game': 'game',
#  'checkers': 'game',
#  'chessboard': 'game',
#  'dice': 'game',
#  'domino': 'game',
#  'game': 'game',
#  'hopscotch': 'game',
#  'jigsaw_puzzle': 'game',
#  'jump_rope': 'sports equipment',
#  'playing_card': 'game',
#  'scrabble': 'game',
#  'shuffleboard': 'game',
#  'ticktacktoe': 'game',
#  'videogame': 'game',
#  'yo-yo': 'toy',
#  'axe': 'weapon',
#  'clipper1': 'tool',
#  'hatchet': 'garden tool',
#  'hoe': 'tool',
#  'hose': 'tool',
#  'lawnmower': 'home appliance',
#  'pickax': 'weapon',
#  'pitchfork': 'weapon',
#  'rake': 'tool',
#  'shears': 'tool',
#  'sickle': 'tool',
#  'bracket': 'hardware',
#  'button2': 'hardware',
#  'cable': 'hardware',
#  'can_opener': 'tool',
#  'charger': 'hardware',
#  'chicken_wire': 'hardware',
#  'cleaver': 'weapon',
#  'coil': 'hardware',
#  'cord': 'hardware',
#  'corkscrew': 'tool',
#  'crank': 'tool',
#  'crowbar': 'weapon',
#  'doorhandle': 'hardware',
#  'doorknob': 'hardware',
#  'doorknocker': 'home decor',
#  'duct': 'hardware',
#  'faucet': 'hardware',
#  'file1': 'tool',
#  'gear': 'hardware',
#  'handle': 'hardware',
#  'hinge': 'hardware',
#  'hook2': 'hardware',
#  'key': 'hardware',
#  'knob': 'hardware',
#  'ladder': 'tool',
#  'light_switch': 'hardware',
#  'lightbulb': 'lighting',
#  'mallet': 'tool',
#  'pipe2': 'hardware',
#  'plug': 'hardware',
#  'plunger': 'tool',
#  'ratchet': 'tool',
#  'scraper': 'tool',
#  'soldering_iron': 'tool',
#  'spark_plug': 'part of car',
#  'strainer': 'kitchen tool',
#  'switch': 'hardware',
#  'thermometer': 'scientific equipment',
#  'tool': 'tool',
#  'tweezers': 'tool',
#  'valve': 'hardware',
#  'vise': 'tool',
#  'wedge': 'tool',
#  'football_helmet': 'sports equipment',
#  'hairnet': 'headwear',
#  'hood': 'headwear',
#  ...}

# %%
sketch_trials = pd.read_csv(os.path.join(data_dir,'things-drawings-prod-clean.csv'))

# %%
### apply things_plus_dict to the uniqueID column in sketch_trials
sketch_trials['category'] = sketch_trials['concept'].map(things_plus_dict)
sketch_trials['category'].value_counts()
# Out:
# category
# food                      3002
# tool                      1483
# container                 1250
# mammal                    1216
# sports equipment           841
# weapon                     790
# vehicle                    756
# furniture                  634
# vegetable                  608
# home decor                 589
# clothing                   565
# musical instrument         542
# body part                  512
# fruit                      500
# electronic device          487
# toy                        475
# hardware                   474
# part of car                464
# plant                      461
# seafood                    423
# personal hygiene item      410
# scientific equipment       404
# bird                       361
# medical equipment          328
# kitchen appliance          325
# women's clothing           312
# school supply              301
# arts and crafts supply     300
# drink                      297
# insect                     267
# game                       260
# home appliance             259
# clothing accessory         251
# animal                     245
# watercraft                 240
# jewelry                    223
# safety equipment           216
# headwear                   206
# sea animal                 192
# lighting                   170
# office supply              146
# fastener                   144
# outerwear                  129
# footwear                   107
# kitchen tool               104
# construction equipment      97
# protective clothing         69
# farm animal                 34
# garden tool                 19
# Name: count, dtype: int64

# %%
# Load the data
image_folder = os.path.join(stimuli_dir, 'sketch_pngs')
# Load the model and tokenizer
model_name = 'google/siglip-so400m-patch14-384'  # Replace with the name of your model
model = AutoModel.from_pretrained(model_name)
processor = AutoProcessor.from_pretrained(model_name)

# %%
def embed_image(image_path):
    image = Image.open(image_path).convert('RGB')
    inputs = processor(text=None, images=image, padding="max_length", return_tensors="pt")
    with torch.no_grad():
        outputs = model.get_image_features(**inputs)
    
   
    return outputs.squeeze().numpy().shape

# Embed all images
embeddings = []
for sketch_id in tqdm(sketch_trials['sketch_id'], desc="Embedding images"):
    image_path = os.path.join(image_folder, f'{sketch_id}.png')  # Adjust the file extension if needed
    embedding = embed_image(image_path)
    embeddings.append(embedding)

embeddings = np.array(embeddings)

# Perform t-SNE
tsne = TSNE(n_components=2, random_state=42)
tsne_results = tsne.fit_transform(embeddings)

# Plot the t-SNE results
plt.figure(figsize=(10, 8))
scatter = plt.scatter(tsne_results[:, 0], tsne_results[:, 1], c=sketch_trials['category'].astype('category').cat.codes, cmap='viridis')
plt.colorbar(scatter, ticks=range(len(sketch_trials['category'].unique())), label='Category')
plt.xlabel('t-SNE 1')
plt.ylabel('t-SNE 2')
plt.title('t-SNE of Sketch Embeddings')
plt.show()
# Out:
# Embedding images:   0%|          | 1/28627 [00:07<58:00:17,  7.29s/it]

# %%
i = Image.open(image_path).convert('RGB')

# %%
# Out:
# (1152,)
